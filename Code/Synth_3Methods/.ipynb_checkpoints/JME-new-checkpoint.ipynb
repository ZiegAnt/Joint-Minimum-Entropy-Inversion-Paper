# %% [markdown]
# # Chapter 4: synthetic data study
# # Best results JME stabilizer
#
#
# <div class="alert alert-success">
#
# This Notebook contains the Code to produce Figures related to the Result comparison between conventional, ME standalone inversion and JME inversion.

# %%
# Importing pygimli
import  pygimli                 as     pg
import  pygimli.meshtools       as     mt
from    pygimli.physics         import ert
from    pygimli.physics         import TravelTimeManager
from    pygimli.viewer.mpl      import createColorBarOnly
from    JointEntropyClass       import JointEntropyInversion as JEI
from    PlotHelpers                 import *
from    pygimli.physics.gravimetry import GravityModelling2D


# Importing auxiliary libraries
import  numpy                   as     np
import  matplotlib.pyplot       as     plt
import  sys
import cmasher                     as cm


# Setting options
seed_val = 420
np.random.seed(seed_val)

# Filenames
fn_ert_dd  = 'Synth_ert_dd2.dat'
fn_tt      = 'Synth_tt2.dat'
fn_grav      = 'Synth_grav2.npy'

# Plotting
c_ert = 'gnuplot'
c_srt = 'viridis'
c_grav = cm.pepper

lim_ert = [5e1, 1e4]
ert_marks = [7e2, 7e3, 7e1]
ert_label = ['Layer1', 'Layer2', 'Anomaly']

lim_srt = [300, 4200]
srt_marks = [5e3, 4e3, 2e3]
srt_label = ['Layer 1', 'Layer 2', 'Anomaly']

lim_grav = [0, 800]
grav_marks = [600, 0]
grav_label = ['Anomaly', 'Half-space']

# %% [markdown]
# ## Geometry for Comparison

# %%
world = mt.createWorld(start=[-45, 0], end=[45, -15], layers=[-9],
                       marker=1)
rect = mt.createRectangle(start=[-6, -3.5], end=[6, -6.0],
                          marker=3, area=0.1)
rect.rotate([0, 0, 0.15])

geom = world + rect
pg.show(geom, markers=True)
# Out:
# (<Axes: >, None)

# %% [markdown]
# ## Data and Inversion Mesh

# %%
# Loading ERT
ert_data = ert.load(fn_ert_dd)
ERT = ert.ERTManager(ert_data)

# Loading SRT
tt_data = pg.physics.traveltime.load(fn_tt)
SRT = TravelTimeManager(tt_data)

grav_data = pg.Vector(np.load(fn_grav))

# inversion mesh
w = mt.createWorld([-65,-20], [65, 0])
for x in np.arange(-64,65,1):
    w.createNode([x,0])
invmesh = mt.createMesh(w,area=1.5)
extmesh = mt.appendTriangleBoundary(invmesh,xbound=100,ybound=100,marker=0)

# fig, ax = plt.subplots(1,3)
# ERT.showData(ert_data, ax=ax[0], cMap=c_ert)
# SRT.showData(tt_data, ax=ax[1], cMap=c_srt)
# pg.show(invmesh, ax=ax[2])

# %% [markdown]
# # Conventional

# %%
v_start = pg.y(invmesh.cellCenters())
for i,z in enumerate(v_start):
    if z>-13:
        v_start[i] = 500
    elif z<-18:
        v_start[i] = 4200
    else:
        v_start[i] = 500+(-z-13)*4500/7

cz = -pg.y(invmesh.cellCenters())
z0 = 5
wz = 1 / (cz+z0)**1.5

# %%
v_est_con = SRT.invert(tt_data, mesh=invmesh, vTop=500, vBottom=3000, lam=6, secNodes=1, verbose=True, maxIter=30)
r_est_con = ERT.invert(ert_data, mesh = extmesh, lam=2, verbose=True)

pnts_grav = np.array([np.linspace(-40,40,81) , np.zeros(81)]).T
fop = GravityModelling2D(mesh=invmesh, points=pnts_grav)
inv = pg.Inversion(fop=fop)
inv.setRegularization(limits=[-5, 800], trans="Cot")
inv.setConstraintWeights(wz)

startModel = pg.Vector(invmesh.cellCount(), 1)

d_est_con = inv.run(grav_data, absoluteError=0.001, startModel=startModel, lam=1000, verbose=True, cType=1, dPhi=0.001, isReference=True)
# Out:
# 27/07/23 - 10:11:46 - pyGIMLi - INFO - Found 1 regions.
# 27/07/23 - 10:11:46 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 27/07/23 - 10:11:46 - pyGIMLi - INFO - Creating refined mesh (secnodes: 1) to solve forward task.
# 27/07/23 - 10:11:46 - pyGIMLi - INFO - Create gradient starting model. 500: 1000
# 27/07/23 - 10:11:46 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00199357 0.0018019  0.00199357 ... 0.00102333 0.00100573 0.00105268]
# 27/07/23 - 10:11:46 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.traveltime.modelling.TravelTimeDijkstraModelling object at 0x000001F5A8F6ECC0>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x000001F5A8F6EDB0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000001F5A8F6ED60>
# min/max (data): 0.0018/0.06
# min/max (error): 0.96%/1.08%
# min/max (start model): 1.0e-03/0.002
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² = 360.21 (dPhi = 84.47%) lam: 6
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² = 197.83 (dPhi = 45.06%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² = 187.8 (dPhi = 5.07%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² = 179.03 (dPhi = 4.67%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² = 163.82 (dPhi = 8.49%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² = 129.61 (dPhi = 20.87%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² = 96.5 (dPhi = 25.52%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² = 74.07 (dPhi = 23.21%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² = 54.88 (dPhi = 25.87%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² = 39.24 (dPhi = 28.44%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... chi² = 30.4 (dPhi = 22.45%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... chi² = 24.73 (dPhi = 18.56%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 13 ... chi² = 19.05 (dPhi = 22.8%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 14 ... chi² = 15.93 (dPhi = 16.27%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 15 ... chi² = 12.5 (dPhi = 21.25%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 16 ... chi² = 10.37 (dPhi = 16.88%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 17 ... chi² = 8.76 (dPhi = 15.25%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 18 ... chi² = 7.63 (dPhi = 12.75%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 19 ... chi² = 6.4 (dPhi = 15.67%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 20 ... chi² = 5.84 (dPhi = 8.59%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 21 ... chi² = 4.77 (dPhi = 17.78%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 22 ... chi² = 4.31 (dPhi = 9.41%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 23 ... chi² = 4.08 (dPhi = 5.05%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 24 ... chi² = 3.81 (dPhi = 6.5%) lam: 6.0
# --------------------------------------------------------------------------------
# inv.iter 25 ...
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Found 2 regions.
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# chi² = 3.73 (dPhi = 1.97%) lam: 6.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.97 (< 2.0%)                 #
# ################################################################################
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Use median(data values)=652.157275215198
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [652.157275215198,...,652.157275215198]
# 27/07/23 - 10:13:32 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000001F5A8F6E950>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x000001F5A8F6E9F0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000001F5A8F6E9A0>
# min/max (data): 301/1222
# min/max (error): 2.5%/2.51%
# min/max (start model): 652/652
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# inv.iter 1 ...

# %%
v_start = 1/SRT.inv.startModel
r_start = ERT.inv.startModel

fig, ax, [cax1, cax2, cax3] = plotJointResultsComparison(invmesh, [r_start, r_est_con], [v_start, v_est_con], [startModel, d_est_con],
                               c_ert, c_srt, c_grav,
                               lim_ert, lim_srt, lim_grav, label_list=['Start model', 'Result'], labels=True,
                               ert_marks=ert_marks, srt_marks=srt_marks,  grav_marks=grav_marks,
                               ert_label=ert_label, srt_label=srt_label, grav_label=grav_label, marks=True,
                               figsize=(15,3.5))

ax[0,0].set_title('ERT', fontsize=16)
ax[0,1].set_title('SRT', fontsize=16)

fig.suptitle(f'    Conventional smoothness-constrained inversion',fontsize=16, y=1.15)

# %% [markdown]
# # Order q=1

# %%
q=1
beta = 1e-10

lam_ert = 3e-3
a_ert = 15

lam_srt = 1e-2
a_srt = 90

lam_grav = 1e-4
a_grav =1

# %% [markdown]
# ## ME

# %%
a = a_grav
lam = lam_grav
beta = beta

fop = GravityModelling2D(mesh=invmesh, points=pnts_grav)
inv = pg.Inversion(fop=fop)
inv.setRegularization(limits=[0, 800])#, trans="Cot")
inv.setConstraintWeights(wz)
GRAV = pg.frameworks.methodManager.MethodManager(fop=fop, fw=inv, data=grav_data)
        
Je = JEI(mgr_list=[GRAV], data_list=[grav_data], mesh=invmesh, order=q, beta=beta, smooth_factor=a)
        
KWe = dict(lam=lam, verbose=True, startModel=startModel)
Je.setKWInv([KWe])
Je.setNames(['GRAV'])

Je.runInversion('ME', maxIter=20, chi_limit=1)

[d_est_me] = Je.getModels()
# Out:
# 26/07/23 - 19:40:31 - pyGIMLi - WARNING - No data error given, set Fallback set to 1%
# 26/07/23 - 19:40:31 - pyGIMLi - INFO - Starting inversion.
# 26/07/23 - 19:40:31 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 19:40:31 - pyGIMLi - INFO - Use median(data values)=0.02094283046510902
# 26/07/23 - 19:40:31 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [0.02094283046510902,...,0.02094283046510902]
# Starting Iteration 0...
# ... GRAV
# fop: <pygimli.physics.gravimetry.gravMagModelling.GravityModelling2D object at 0x000002827D0E3810>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x0000028220738D60>
# Model transformation (cumulative):
# 	 0 <pgcore._pygimli_.RTransLogLU object at 0x00000282207382E0>
# min/max (data): 0.0029/0.09
# min/max (error): 1%/1%
# min/max (start model): 1/1
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² = 1211.26 (dPhi = 86.54%) lam: 0.0001
# Starting iteration 1...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 1128.51
# #####     stabilizing functional    S = 7.99
# #####     joint weighted misfit chi^2 = 1128.51
# ############################################################
#
# Starting iteration 2...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 865.36
# #####     stabilizing functional    S = 8.02
# #####     joint weighted misfit chi^2 = 865.36
# ############################################################
#
# Starting iteration 3...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 768.00
# #####     stabilizing functional    S = 7.89
# #####     joint weighted misfit chi^2 = 768.00
# ############################################################
#
# Starting iteration 4...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 710.60
# #####     stabilizing functional    S = 7.89
# #####     joint weighted misfit chi^2 = 710.60
# ############################################################
#
# Starting iteration 5...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 533.18
# #####     stabilizing functional    S = 7.77
# #####     joint weighted misfit chi^2 = 533.18
# ############################################################
#
# Starting iteration 6...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 382.90
# #####     stabilizing functional    S = 7.77
# #####     joint weighted misfit chi^2 = 382.90
# ############################################################
#
# Starting iteration 7...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 316.73
# #####     stabilizing functional    S = 7.83
# #####     joint weighted misfit chi^2 = 316.73
# ############################################################
#
# Starting iteration 8...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 239.19
# #####     stabilizing functional    S = 7.78
# #####     joint weighted misfit chi^2 = 239.19
# ############################################################
#
# Starting iteration 9...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 158.43
# #####     stabilizing functional    S = 7.63
# #####     joint weighted misfit chi^2 = 158.43
# ############################################################
#
# Starting iteration 10...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 87.93
# #####     stabilizing functional    S = 7.07
# #####     joint weighted misfit chi^2 = 87.93
# ############################################################
#
# Starting iteration 11...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 72.77
# #####     stabilizing functional    S = 7.77
# #####     joint weighted misfit chi^2 = 72.77
# ############################################################
#
# Starting iteration 12...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 80.60
# #####     stabilizing functional    S = 7.80
# #####     joint weighted misfit chi^2 = 80.60
# ############################################################
#
# Starting iteration 13...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 27.37
# #####     stabilizing functional    S = 7.52
# #####     joint weighted misfit chi^2 = 27.37
# ############################################################
#
# Starting iteration 14...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 8.57
# #####     stabilizing functional    S = 12.90
# #####     joint weighted misfit chi^2 = 8.57
# ############################################################
#
# Starting iteration 15...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 4.70
# #####     stabilizing functional    S = 7.89
# #####     joint weighted misfit chi^2 = 4.70
# ############################################################
#
# Starting iteration 16...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 3.93
# #####     stabilizing functional    S = 7.87
# #####     joint weighted misfit chi^2 = 3.93
# ############################################################
#
# Starting iteration 17...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 2.94
# #####     stabilizing functional    S = 7.84
# #####     joint weighted misfit chi^2 = 2.94
# ############################################################
#
# Starting iteration 18...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 2.72
# #####     stabilizing functional    S = 7.88
# #####     joint weighted misfit chi^2 = 2.72
# ############################################################
#
# Starting iteration 19...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 2.20
# #####     stabilizing functional    S = 7.86
# #####     joint weighted misfit chi^2 = 2.20
# ############################################################
#
# Starting iteration 20...
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     GRAV weighted misfit chi^2   = 1.67
# #####     stabilizing functional    S = 7.86
# #####     joint weighted misfit chi^2 = 1.67
# ############################################################
#
# All weights saved under self.weights

# %%
# ERT
a = a_ert
lam = lam_ert
beta = beta

ERT2 = ert.ERTManager(ert_data)
Je = JEI(mgr_list=[ERT2], data_list=[ert_data], mesh=invmesh, order=q, beta=beta, smooth_factor=a)

KWe = dict(lam=lam, verbose=False)
Je.setKWInv([KWe])
Je.setNames(['ERT'])
Je.setMethodMesh(extmesh, 0)

Je.runInversion('ME', maxIter=10, chi_limit=1)
ERT2.showResultAndFit(cMap=c_ert)

[r_est_me] = Je.getModels()
# Out:
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Found 2 regions.
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Creating forward mesh from region infos.
# Starting Iteration 0...
# ... ERT
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Use median(data values)=619.288890298902
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [619.288890298902,...,619.288890298902]
# 26/07/23 - 19:40:36 - pyGIMLi - INFO - Setting starting model as reference!
# Starting iteration 1...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 3.62
# #####     stabilizing functional    S = 7407.59
# #####     joint weighted misfit chi^2 = 3.62
# ############################################################
#
# Starting iteration 2...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 2.42
# #####     stabilizing functional    S = 327.93
# #####     joint weighted misfit chi^2 = 2.42
# ############################################################
#
# Starting iteration 3...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 2.06
# #####     stabilizing functional    S = 33.13
# #####     joint weighted misfit chi^2 = 2.06
# ############################################################
#
# Starting iteration 4...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 1.32
# #####     stabilizing functional    S = 65.85
# #####     joint weighted misfit chi^2 = 1.32
# ############################################################
#
# Starting iteration 5...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 1.03
# #####     stabilizing functional    S = 100.65
# #####     joint weighted misfit chi^2 = 1.03
# ############################################################
#
# Starting iteration 6...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 0.94
# #####     stabilizing functional    S = 294.00
# #####     joint weighted misfit chi^2 = 0.94
# ############################################################
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           joint chi^2 < 1.00
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# All weights saved under self.weights

# %%
# SRT
a = a_srt
lam = lam_srt
beta = beta

SRT2 = TravelTimeManager(tt_data)
Js = JEI(mgr_list=[SRT2], data_list=[tt_data], mesh=invmesh, order=q, beta=beta, smooth_factor=a)

KWs = dict(lam=lam, verbose=False, vTop=500, vBottom=1000, secNodes=1)
Js.setKWInv([KWs])
Js.setNames(['SRT'])

Js.runInversion('ME', maxIter=20, chi_limit=1.5)
SRT2.inv.model = 1/SRT2.inv.model
SRT2.showResultAndFit(cMap=c_srt)

[v_est_me] = Js.getModels()
# Out:
# 26/07/23 - 19:44:09 - pyGIMLi - INFO - Found 1 regions.
# 26/07/23 - 19:44:09 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 19:44:09 - pyGIMLi - INFO - Creating refined mesh (secnodes: 1) to solve forward task.
# Starting Iteration 0...
# ... SRT
# 26/07/23 - 19:44:09 - pyGIMLi - INFO - Create gradient starting model. 500: 1000
# 26/07/23 - 19:44:09 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00199357 0.0018019  0.00199357 ... 0.00102333 0.00100573 0.00105268]
# 26/07/23 - 19:44:09 - pyGIMLi - INFO - Setting starting model as reference!
# Starting iteration 1...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 227.18
# #####     stabilizing functional    S = 1618.47
# #####     joint weighted misfit chi^2 = 227.18
# ############################################################
#
# Starting iteration 2...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 153.16
# #####     stabilizing functional    S = 47.66
# #####     joint weighted misfit chi^2 = 153.16
# ############################################################
#
# Starting iteration 3...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 109.32
# #####     stabilizing functional    S = 168.02
# #####     joint weighted misfit chi^2 = 109.32
# ############################################################
#
# Starting iteration 4...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 45.64
# #####     stabilizing functional    S = 28.44
# #####     joint weighted misfit chi^2 = 45.64
# ############################################################
#
# Starting iteration 5...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 28.57
# #####     stabilizing functional    S = 56.74
# #####     joint weighted misfit chi^2 = 28.57
# ############################################################
#
# Starting iteration 6...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 17.01
# #####     stabilizing functional    S = 20.94
# #####     joint weighted misfit chi^2 = 17.01
# ############################################################
#
# Starting iteration 7...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 10.54
# #####     stabilizing functional    S = 16.65
# #####     joint weighted misfit chi^2 = 10.54
# ############################################################
#
# Starting iteration 8...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 6.14
# #####     stabilizing functional    S = 12.85
# #####     joint weighted misfit chi^2 = 6.14
# ############################################################
#
# Starting iteration 9...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.31
# #####     stabilizing functional    S = 289.41
# #####     joint weighted misfit chi^2 = 4.31
# ############################################################
#
# Starting iteration 10...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 3.19
# #####     stabilizing functional    S = 11.45
# #####     joint weighted misfit chi^2 = 3.19
# ############################################################
#
# Starting iteration 11...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 2.55
# #####     stabilizing functional    S = 9.17
# #####     joint weighted misfit chi^2 = 2.55
# ############################################################
#
# Starting iteration 12...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 1.99
# #####     stabilizing functional    S = 17.30
# #####     joint weighted misfit chi^2 = 1.99
# ############################################################
#
# Starting iteration 13...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 1.92
# #####     stabilizing functional    S = 8.49
# #####     joint weighted misfit chi^2 = 1.92
# ############################################################
#
# Starting iteration 14...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 1.56
# #####     stabilizing functional    S = 7.99
# #####     joint weighted misfit chi^2 = 1.56
# ############################################################
#
# Starting iteration 15...
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 1.31
# #####     stabilizing functional    S = 9.32
# #####     joint weighted misfit chi^2 = 1.31
# ############################################################
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           joint chi^2 < 1.50
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# All weights saved under self.weights

# %%
fig, ax, [cax1, cax2, cax3] = plotJointResultsComparison(invmesh, [r_est_me],  [v_est_me], [d_est_me], 
                                                   c_ert, c_srt, c_grav,
                                                   lim_ert, lim_srt, lim_grav, label_list=['Start model', 'Result'], labels=True,
                                                   ert_marks=ert_marks, srt_marks=srt_marks,  grav_marks=grav_marks,
                                                   ert_label=ert_label, srt_label=srt_label, grav_label=grav_label, marks=True,)
# Out:
# bla

# %% [markdown]
# ## JME

# %%
# Without weighting
a = [a_ert, a_srt, a_grav]
lam = [lam_ert, lam_srt, lam_grav]
beta = beta
w1 = 1 # weight ert
w2 = 1 # weight srt
w3 = 1

ERT3 = ert.ERTManager(ert_data)
SRT3 = TravelTimeManager(tt_data)
fop = GravityModelling2D(mesh=invmesh, points=pnts_grav)
inv = pg.Inversion(fop=fop)
inv.setRegularization(limits=[0, 800])#, trans="Cot")
inv.setConstraintWeights(wz)
GRAV = pg.frameworks.methodManager.MethodManager(fop=fop, fw=inv, data=grav_data)

J1 = JEI(mgr_list=[ERT3,SRT3,GRAV], data_list=[ert_data,tt_data,grav_data], 
         mesh=invmesh, order=q, beta=beta,smooth_factor=a)

KWs = dict(lam=lam[1], verbose=False, vTop=500, vBottom=1000, secNodes=2)
KWe = dict(lam=lam[0], verbose=False)
KWg = dict(lam=lam[2], verbose=True, startModel=startModel)

J1.setMethodMesh(extmesh, 0)
J1.setKWInv([KWe, KWs, KWg])
J1.setNames(['ERT','SRT', 'GRAV'])
J1.setMethodWeights([w1,w2,w3])

J1.runInversion('ME', maxIter=20, breakup_criterion='all', chi_limit=1)
SRT3.inv.model = 1/SRT3.inv.model

[r_est_jme, v_est_jme, d_est_jme] = J1.getModels()
    
J1.plotFitHistory()
# Out:
# 26/07/23 - 19:45:51 - pyGIMLi - INFO - Found 2 regions.
# 26/07/23 - 19:45:51 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 26/07/23 - 19:45:51 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 19:45:52 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/07/23 - 19:45:52 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# Starting Iteration 0...
# ... ERT
# 26/07/23 - 19:45:52 - pyGIMLi - INFO - Use median(data values)=619.288890298902
# 26/07/23 - 19:45:52 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [619.288890298902,...,619.288890298902]
# 26/07/23 - 19:45:52 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 19:46:29 - pyGIMLi - INFO - Found 1 regions.
# 26/07/23 - 19:46:29 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 19:46:29 - pyGIMLi - INFO - Creating refined mesh (secnodes: 2) to solve forward task.
# ... SRT
# 26/07/23 - 19:46:29 - pyGIMLi - INFO - Create gradient starting model. 500: 1000
# 26/07/23 - 19:46:29 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00199357 0.0018019  0.00199357 ... 0.00102333 0.00100573 0.00105268]
# 26/07/23 - 19:46:29 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 19:46:42 - pyGIMLi - WARNING - No data error given, set Fallback set to 1%
# 26/07/23 - 19:46:42 - pyGIMLi - INFO - Starting inversion.
# 26/07/23 - 19:46:42 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 19:46:42 - pyGIMLi - INFO - Use median(data values)=0.02094283046510902
# ... GRAV
# fop: <pygimli.physics.gravimetry.gravMagModelling.GravityModelling2D object at 0x0000028290689EF0>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x0000028281F5FEE0>
# Model transformation (cumulative):
# 	 0 <pgcore._pygimli_.RTransLogLU object at 0x0000028281F49E80>
# min/max (data): 0.0029/0.09
# min/max (error): 1%/1%
# min/max (start model): 1/1
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² = 1211.26 (dPhi = 86.54%) lam: 0.0001
# Starting iteration 1...
# 26/07/23 - 19:46:42 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [0.02094283046510902,...,0.02094283046510902]
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 5.03
# #####     SRT weighted misfit chi^2   = 257.75
# #####     GRAV weighted misfit chi^2   = 1130.12
# #####     stabilizing functional    S = 74.02
# #####     joint weighted misfit chi^2 = 1392.90
# ############################################################
#
# Starting iteration 2...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 1.36
# #####     SRT weighted misfit chi^2   = 174.81
# #####     GRAV weighted misfit chi^2   = 864.37
# #####     stabilizing functional    S = 976.01
# #####     joint weighted misfit chi^2 = 1040.54
# ############################################################
#
# Starting iteration 3...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 1.06
# #####     SRT weighted misfit chi^2   = 146.00
# #####     GRAV weighted misfit chi^2   = 767.51
# #####     stabilizing functional    S = 96.60
# #####     joint weighted misfit chi^2 = 914.57
# ############################################################
#
# Starting iteration 4...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.94
# #####     SRT weighted misfit chi^2   = 103.72
# #####     GRAV weighted misfit chi^2   = 632.77
# #####     stabilizing functional    S = 18.33
# #####     joint weighted misfit chi^2 = 737.44
# ############################################################
#
# Starting iteration 5...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.93
# #####     SRT weighted misfit chi^2   = 72.25
# #####     GRAV weighted misfit chi^2   = 505.99
# #####     stabilizing functional    S = 10.13
# #####     joint weighted misfit chi^2 = 579.17
# ############################################################
#
# Starting iteration 6...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.90
# #####     SRT weighted misfit chi^2   = 55.39
# #####     GRAV weighted misfit chi^2   = 352.93
# #####     stabilizing functional    S = 8.54
# #####     joint weighted misfit chi^2 = 409.22
# ############################################################
#
# Starting iteration 7...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 40.89
# #####     GRAV weighted misfit chi^2   = 292.73
# #####     stabilizing functional    S = 40.35
# #####     joint weighted misfit chi^2 = 334.50
# ############################################################
#
# Starting iteration 8...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 29.46
# #####     GRAV weighted misfit chi^2   = 217.88
# #####     stabilizing functional    S = 43.46
# #####     joint weighted misfit chi^2 = 248.23
# ############################################################
#
# Starting iteration 9...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 26.26
# #####     GRAV weighted misfit chi^2   = 144.31
# #####     stabilizing functional    S = 8.11
# #####     joint weighted misfit chi^2 = 171.45
# ############################################################
#
# Starting iteration 10...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 21.50
# #####     GRAV weighted misfit chi^2   = 84.53
# #####     stabilizing functional    S = 8.96
# #####     joint weighted misfit chi^2 = 106.92
# ############################################################
#
# Starting iteration 11...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 18.09
# #####     GRAV weighted misfit chi^2   = 79.97
# #####     stabilizing functional    S = 14.11
# #####     joint weighted misfit chi^2 = 98.94
# ############################################################
#
# Starting iteration 12...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 11.91
# #####     GRAV weighted misfit chi^2   = 73.26
# #####     stabilizing functional    S = 11.23
# #####     joint weighted misfit chi^2 = 86.05
# ############################################################
#
# Starting iteration 13...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 10.21
# #####     GRAV weighted misfit chi^2   = 42.59
# #####     stabilizing functional    S = 8.20
# #####     joint weighted misfit chi^2 = 53.67
# ############################################################
#
# Starting iteration 14...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 8.45
# #####     GRAV weighted misfit chi^2   = 12.54
# #####     stabilizing functional    S = 9.50
# #####     joint weighted misfit chi^2 = 21.87
# ############################################################
#
# Starting iteration 15...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 6.44
# #####     GRAV weighted misfit chi^2   = 9.97
# #####     stabilizing functional    S = 46.94
# #####     joint weighted misfit chi^2 = 17.29
# ############################################################
#
# Starting iteration 16...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 5.78
# #####     GRAV weighted misfit chi^2   = 4.06
# #####     stabilizing functional    S = 10.12
# #####     joint weighted misfit chi^2 = 10.72
# ############################################################
#
# Starting iteration 17...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 5.01
# #####     GRAV weighted misfit chi^2   = 0.97
# #####     stabilizing functional    S = 8.10
# #####     joint weighted misfit chi^2 = 6.86
# ############################################################
#
# Starting iteration 18...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 4.22
# #####     GRAV weighted misfit chi^2   = 0.70
# #####     stabilizing functional    S = 11.23
# #####     joint weighted misfit chi^2 = 5.80
# ############################################################
#
# Starting iteration 19...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 3.80
# #####     GRAV weighted misfit chi^2   = 0.41
# #####     stabilizing functional    S = 8.00
# #####     joint weighted misfit chi^2 = 5.10
# ############################################################
#
# Starting iteration 20...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 3.33
# #####     GRAV weighted misfit chi^2   = 0.25
# #####     stabilizing functional    S = 7.95
# #####     joint weighted misfit chi^2 = 4.46
# ############################################################
#
# All weights saved under self.weights

# %%
fig, ax, [cax1, cax2, cax3] = plotJointResultsComparison(invmesh, [r_est_jme],  [v_est_jme], [d_est_jme], 
                                                   c_ert, c_srt, c_grav,
                                                   lim_ert, lim_srt, lim_grav, label_list=['ME'], labels=True,
                                                   ert_marks=ert_marks, srt_marks=srt_marks,  grav_marks=grav_marks,
                                                   ert_label=ert_label, srt_label=srt_label, grav_label=grav_label, marks=True,)
# Out:
# bla

# %%
# With weighting
a = [a_ert, a_srt, a_grav]
lam = [lam_ert, lam_srt, lam_grav]
beta = beta
w1 = 5 # weight ert
w2 = 2 # weight srt
w3 = 1

ERT4 = ert.ERTManager(ert_data)
SRT4 = TravelTimeManager(tt_data)
fop = GravityModelling2D(mesh=invmesh, points=pnts_grav)
inv = pg.Inversion(fop=fop)
inv.setRegularization(limits=[0, 800])#, trans="Cot")
inv.setConstraintWeights(wz)
GRAV = pg.frameworks.methodManager.MethodManager(fop=fop, fw=inv, data=grav_data)

J2 = JEI(mgr_list=[ERT4,SRT4,GRAV], data_list=[ert_data,tt_data,grav_data], 
         mesh=invmesh, order=q, beta=beta,smooth_factor=a)

KWs = dict(lam=lam[1], verbose=False, vTop=500, vBottom=1000, secNodes=2)
KWe = dict(lam=lam[0], verbose=False)
KWg = dict(lam=lam[2], verbose=True, startModel=startModel)

J2.setMethodMesh(extmesh, 0)
J2.setKWInv([KWe, KWs, KWg])
J2.setNames(['ERT','SRT', 'GRAV'])
J2.setMethodWeights([w1,w2,w3])

J2.runInversion('ME', maxIter=20, breakup_criterion='all', chi_limit=1)
SRT3.inv.model = 1/SRT3.inv.model

[r_est_jmew, v_est_jmew, d_est_jmew] = J2.getModels()

J2.plotFitHistory()
# Out:
# 26/07/23 - 20:03:47 - pyGIMLi - INFO - Found 2 regions.
# 26/07/23 - 20:03:47 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 26/07/23 - 20:03:47 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:03:47 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# Starting Iteration 0...
# ... ERT
# 26/07/23 - 20:03:48 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# 26/07/23 - 20:03:48 - pyGIMLi - INFO - Use median(data values)=619.288890298902
# 26/07/23 - 20:03:48 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [619.288890298902,...,619.288890298902]
# 26/07/23 - 20:03:48 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 20:04:29 - pyGIMLi - INFO - Found 1 regions.
# 26/07/23 - 20:04:29 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:04:29 - pyGIMLi - INFO - Creating refined mesh (secnodes: 2) to solve forward task.
# ... SRT
# 26/07/23 - 20:04:29 - pyGIMLi - INFO - Create gradient starting model. 500: 1000
# 26/07/23 - 20:04:29 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00199357 0.0018019  0.00199357 ... 0.00102333 0.00100573 0.00105268]
# 26/07/23 - 20:04:29 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 20:04:43 - pyGIMLi - WARNING - No data error given, set Fallback set to 1%
# 26/07/23 - 20:04:43 - pyGIMLi - INFO - Starting inversion.
# 26/07/23 - 20:04:43 - pyGIMLi - INFO - Setting starting model as reference!
# ... GRAV
# fop: <pygimli.physics.gravimetry.gravMagModelling.GravityModelling2D object at 0x00000282C0AD93B0>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x0000028281990A60>
# Model transformation (cumulative):
# 	 0 <pgcore._pygimli_.RTransLogLU object at 0x00000282C0AC08E0>
# min/max (data): 0.0029/0.09
# min/max (error): 1%/1%
# min/max (start model): 1/1
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² = 1211.26 (dPhi = 86.54%) lam: 0.0001
# Starting iteration 1...
# 26/07/23 - 20:04:43 - pyGIMLi - INFO - Use median(data values)=0.02094283046510902
# 26/07/23 - 20:04:43 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [0.02094283046510902,...,0.02094283046510902]
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 4.46
# #####     SRT weighted misfit chi^2   = 243.67
# #####     GRAV weighted misfit chi^2   = 1130.12
# #####     stabilizing functional    S = 538.33
# #####     joint weighted misfit chi^2 = 1378.25
# ############################################################
#
# Starting iteration 2...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 2.04
# #####     SRT weighted misfit chi^2   = 150.78
# #####     GRAV weighted misfit chi^2   = 862.49
# #####     stabilizing functional    S = 2040.59
# #####     joint weighted misfit chi^2 = 1015.31
# ############################################################
#
# Starting iteration 3...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.98
# #####     SRT weighted misfit chi^2   = 103.08
# #####     GRAV weighted misfit chi^2   = 781.03
# #####     stabilizing functional    S = 67.66
# #####     joint weighted misfit chi^2 = 885.09
# ############################################################
#
# Starting iteration 4...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.93
# #####     SRT weighted misfit chi^2   = 77.12
# #####     GRAV weighted misfit chi^2   = 722.65
# #####     stabilizing functional    S = 141.85
# #####     joint weighted misfit chi^2 = 800.70
# ############################################################
#
# Starting iteration 5...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.90
# #####     SRT weighted misfit chi^2   = 50.48
# #####     GRAV weighted misfit chi^2   = 550.24
# #####     stabilizing functional    S = 17.61
# #####     joint weighted misfit chi^2 = 601.63
# ############################################################
#
# Starting iteration 6...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 39.32
# #####     GRAV weighted misfit chi^2   = 398.67
# #####     stabilizing functional    S = 10.02
# #####     joint weighted misfit chi^2 = 438.88
# ############################################################
#
# Starting iteration 7...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 30.16
# #####     GRAV weighted misfit chi^2   = 341.18
# #####     stabilizing functional    S = 8.40
# #####     joint weighted misfit chi^2 = 372.23
# ############################################################
#
# Starting iteration 8...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 23.29
# #####     GRAV weighted misfit chi^2   = 273.70
# #####     stabilizing functional    S = 11.78
# #####     joint weighted misfit chi^2 = 297.87
# ############################################################
#
# Starting iteration 9...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 16.49
# #####     GRAV weighted misfit chi^2   = 193.30
# #####     stabilizing functional    S = 16.73
# #####     joint weighted misfit chi^2 = 210.68
# ############################################################
#
# Starting iteration 10...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 10.92
# #####     GRAV weighted misfit chi^2   = 118.38
# #####     stabilizing functional    S = 24.24
# #####     joint weighted misfit chi^2 = 130.19
# ############################################################
#
# Starting iteration 11...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 7.36
# #####     GRAV weighted misfit chi^2   = 75.94
# #####     stabilizing functional    S = 8.84
# #####     joint weighted misfit chi^2 = 84.18
# ############################################################
#
# Starting iteration 12...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 4.82
# #####     GRAV weighted misfit chi^2   = 66.47
# #####     stabilizing functional    S = 14.24
# #####     joint weighted misfit chi^2 = 72.18
# ############################################################
#
# Starting iteration 13...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 4.01
# #####     GRAV weighted misfit chi^2   = 43.21
# #####     stabilizing functional    S = 7.82
# #####     joint weighted misfit chi^2 = 48.11
# ############################################################
#
# Starting iteration 14...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 3.31
# #####     GRAV weighted misfit chi^2   = 10.34
# #####     stabilizing functional    S = 10.43
# #####     joint weighted misfit chi^2 = 14.53
# ############################################################
#
# Starting iteration 15...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 2.64
# #####     GRAV weighted misfit chi^2   = 0.50
# #####     stabilizing functional    S = 8.06
# #####     joint weighted misfit chi^2 = 4.02
# ############################################################
#
# Starting iteration 16...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 2.19
# #####     GRAV weighted misfit chi^2   = 0.15
# #####     stabilizing functional    S = 10.20
# #####     joint weighted misfit chi^2 = 3.22
# ############################################################
#
# Starting iteration 17...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 1.91
# #####     GRAV weighted misfit chi^2   = 0.02
# #####     stabilizing functional    S = 10.62
# #####     joint weighted misfit chi^2 = 2.81
# ############################################################
#
# Starting iteration 18...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 1.69
# #####     GRAV weighted misfit chi^2   = 0.02
# #####     stabilizing functional    S = 10.53
# #####     joint weighted misfit chi^2 = 2.59
# ############################################################
#
# Starting iteration 19...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 1.51
# #####     GRAV weighted misfit chi^2   = 0.01
# #####     stabilizing functional    S = 8.28
# #####     joint weighted misfit chi^2 = 2.40
# ############################################################
#
# Starting iteration 20...
# Set JME weights for ERT with q=1, b=1e-10 and a=15
# Set JME weights for SRT with q=1, b=1e-10 and a=90
# Set JME weights for GRAV with q=1, b=1e-10 and a=1
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 1.43
# #####     GRAV weighted misfit chi^2   = 0.02
# #####     stabilizing functional    S = 9.31
# #####     joint weighted misfit chi^2 = 2.33
# ############################################################
#
# All weights saved under self.weights

# %% [markdown]
# ## Comparison Results

# %%
J1.plotFitHistory()
J2.plotFitHistory()

# %%
fig, ax, [cax1, cax2, cax] = plotJointResultsComparison(invmesh, 
                                                   [r_est_con, r_est_me, r_est_jme, r_est_jmew], 
                                                   [v_est_con, v_est_me, v_est_jme, 1/v_est_jmew],
                                                   [d_est_con, d_est_me, d_est_jme, d_est_jmew],
                                                   c_ert, c_srt, c_grav, lim_ert, lim_srt, lim_grav,
                                                   ['Conventional','ME','JME - no weight','JME'], labels=True,
                                                   ert_marks=ert_marks, srt_marks=srt_marks, grav_marks=grav_marks, marks=True,
                                                   ert_label=ert_label, srt_label=srt_label, grav_label=grav_label,  
                                                   figsize=(15,7))
# for axis_ar in ax:
#     for axis in axis_ar:
#         pg.viewer.mpl.drawPLC(axis, geom, fillRegion=False)
#         axis.set_xlim(-35,35)
#         axis.set_ylim(-20,0)
# fig.suptitle(f'Results for q = {q}',fontsize=16, x=0.51, y=1.05)
# ax[0,0].set_title('ERT',fontsize=15)
# ax[0,1].set_title('SRT',fontsize=15)
# for a in ax[:,0]:
#     a.set_ylabel('Z (m)', fontsize=12)
#     a.set_yticks([-20,-10,0])
# for a in ax[-1,:]:
#     a.set_xlabel('X (m)', fontsize=12)
#     a.set_xticks([-20,0,20])
    
# cax1.set_xlabel(pg.unit('vel'), fontsize=12)
# cax1.tick_params(labelsize=12)
# cax2.set_xlabel(pg.unit('res'), fontsize=12)
# cax2.tick_params(labelsize=12)

# %%
# %matplotlib qt
J2.plotWeights('ME',step=9)

# %% [markdown]
# ## Comparison Misfit

# %%
lim = [-10,10] # Misfit limits
label_list = ['Conventional','ME','JME - no weight','JME - weight=[2,1]']
srt_mgrs = [SRT,SRT2,SRT3,SRT4]
ert_resp = [m.inv.response.array() for m in [ERT,ERT2,ERT3,ERT4]]

cmap='coolwarm'

fig, ax = plt.subplots(4,2, figsize=(10,10))

for i in range(4):
    # Plot misfits
    e_misfit =  100*(ert_data['rhoa'].array()-ert_resp[i])/ert_data['rhoa'].array()
    showPseudosections(ert_data, e_misfit, [0,len(ert_data['a'])], 1, ax=ax[i,0], clim=lim, cmap=cmap, Type='misfit', 
                       annotation=False, colorBar=False)
    
    showTTMatrix(srt_mgrs[i], 'misfit', ax[i,1], lim=lim, cmap=cmap, colorBar=False)
    
    # Add labels
    for axis in [ax[i,0],ax[i,1]]:
        axis.text(3, 55, label_list[i], fontsize=10, bbox={'facecolor': 'white', 'alpha': 0.8, 'pad': 5})

# Adjust axes
for ax_ar in ax[:-1,:]:
    for axis in ax_ar:
        axis.set_xticks([])  
        axis.set_xlabel('')

# Add colorbar
cax = ax[-1,0].inset_axes([0.2, -0.45, 1.6, 0.1])
createColorBarOnly(ax=cax, cMin=lim[0], cMax=lim[1], logScale=False,cMap=cmap,
                   label='Misfit (%)', orientation='horizontal')
cax.set_xlabel('Misfit (%)', fontsize=12)
cax.tick_params(labelsize=12)

fig.suptitle(f'Misfit for q = {q}',fontsize=16, x=.51, y=.92)
ax[0,0].set_title('ERT',fontsize=15)
ax[0,1].set_title('SRT',fontsize=15)

for a in ax[:,0]:
    a.set_ylabel('Level', fontsize=12)
    a.set_yticks([0,20,40,60])
    
for a in ax[:,1]:
    a.set_ylabel('Source Index', fontsize=12)
    
ax[-1,0].set_xlabel('Midpoint Index', fontsize=12)
ax[-1,1].set_xlabel('Sensor Index', fontsize=12)
ax[-1,1].set_xticks([0,40,80,120])
# plt.savefig(f'C:/Users/azieg/Desktop/GIT_repositories/APG-MSc-Project-Ziegon/Figures/Ch-4/Best_misfit_comp_{q}.pdf', 
#             bbox_inches='tight',
#             dpi=600)
# Out:
# C:\Users\azieg\Desktop\GIT_repositories\APG-MSc-Project-Ziegon\Code\Synth_3Methods\PlotHelpers.py:308: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ylab)
# [<matplotlib.axis.XTick at 0x282f4ff5ac0>,
#  <matplotlib.axis.XTick at 0x282f4ff5a90>,
#  <matplotlib.axis.XTick at 0x282f4ff56a0>,
#  <matplotlib.axis.XTick at 0x282f520a0d0>]

# %% [markdown]
# # Order q=2

# %%
q=2

# %% [markdown]
# ## ME

# %%
# ERT
a = a_ert
lam = lam_ert
beta = beta

ERT2 = ert.ERTManager(ert_data)
Je = JEI(mgr_list=[ERT2], data_list=[ert_data], mesh=invmesh, order=q, beta=beta, smooth_factor=a)

KWe = dict(lam=lam, verbose=False)
Je.setKWInv([KWe])
Je.setNames(['ERT'])
Je.setMethodMesh(extmesh, 0)

Je.runInversion('ME', maxIter=10, chi_limit=1)
ERT2.showResultAndFit(cMap=c_ert)

[r_est_me] = Je.getModels()
# Out:
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Found 2 regions.
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# Starting Iteration 0...
# ... ERT
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Use median(data values)=619.288890298902
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [619.288890298902,...,619.288890298902]
# 26/07/23 - 20:20:28 - pyGIMLi - INFO - Setting starting model as reference!
# Starting iteration 1...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 4.89
# #####     stabilizing functional    S = 8.16
# #####     joint weighted misfit chi^2 = 4.89
# ############################################################
#
# Starting iteration 2...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 1.08
# #####     stabilizing functional    S = 5.75
# #####     joint weighted misfit chi^2 = 1.08
# ############################################################
#
# Starting iteration 3...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# #####     ERT weighted misfit chi^2   = 0.92
# #####     stabilizing functional    S = 5.54
# #####     joint weighted misfit chi^2 = 0.92
# ############################################################
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           joint chi^2 < 1.00
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# All weights saved under self.weights

# %%
# SRT
a = a_srt
lam = lam_srt
beta = beta

SRT2 = TravelTimeManager(tt_data)
Js = JEI(mgr_list=[SRT2], data_list=[tt_data], mesh=invmesh, order=q, beta=beta, smooth_factor=a)

KWs = dict(lam=lam, verbose=False, vTop=500, vBottom=4500, secNodes=1)
Js.setKWInv([KWs])
Js.setNames(['SRT'])

Js.runInversion('ME', maxIter=20, chi_limit=1.5)
SRT2.inv.model = 1/SRT2.inv.model
SRT2.showResultAndFit(cMap=c_srt)

[v_est_me] = Js.getModels()
# Out:
# 26/07/23 - 20:22:39 - pyGIMLi - INFO - Found 1 regions.
# 26/07/23 - 20:22:39 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:22:39 - pyGIMLi - INFO - Creating refined mesh (secnodes: 1) to solve forward task.
# 26/07/23 - 20:22:39 - pyGIMLi - INFO - Create gradient starting model. 500: 4500
# Starting Iteration 0...
# ... SRT
# 26/07/23 - 20:22:39 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00194971 0.0010641  0.00194971 ... 0.00023161 0.0002245  0.00024393]
# 26/07/23 - 20:22:39 - pyGIMLi - INFO - Setting starting model as reference!
# Starting iteration 1...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 175.49
# #####     stabilizing functional    S = 20.56
# #####     joint weighted misfit chi^2 = 175.49
# ############################################################
#
# Starting iteration 2...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 63.28
# #####     stabilizing functional    S = 3.66
# #####     joint weighted misfit chi^2 = 63.28
# ############################################################
#
# Starting iteration 3...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 30.38
# #####     stabilizing functional    S = 21.54
# #####     joint weighted misfit chi^2 = 30.38
# ############################################################
#
# Starting iteration 4...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 24.64
# #####     stabilizing functional    S = 9.51
# #####     joint weighted misfit chi^2 = 24.64
# ############################################################
#
# Starting iteration 5...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 17.13
# #####     stabilizing functional    S = 9.13
# #####     joint weighted misfit chi^2 = 17.13
# ############################################################
#
# Starting iteration 6...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 13.25
# #####     stabilizing functional    S = 8.44
# #####     joint weighted misfit chi^2 = 13.25
# ############################################################
#
# Starting iteration 7...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 11.60
# #####     stabilizing functional    S = 7.94
# #####     joint weighted misfit chi^2 = 11.60
# ############################################################
#
# Starting iteration 8...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 8.99
# #####     stabilizing functional    S = 8.45
# #####     joint weighted misfit chi^2 = 8.99
# ############################################################
#
# Starting iteration 9...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 7.66
# #####     stabilizing functional    S = 7.54
# #####     joint weighted misfit chi^2 = 7.66
# ############################################################
#
# Starting iteration 10...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 6.62
# #####     stabilizing functional    S = 7.69
# #####     joint weighted misfit chi^2 = 6.62
# ############################################################
#
# Starting iteration 11...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 6.05
# #####     stabilizing functional    S = 7.55
# #####     joint weighted misfit chi^2 = 6.05
# ############################################################
#
# Starting iteration 12...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 5.56
# #####     stabilizing functional    S = 7.53
# #####     joint weighted misfit chi^2 = 5.56
# ############################################################
#
# Starting iteration 13...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 5.20
# #####     stabilizing functional    S = 7.50
# #####     joint weighted misfit chi^2 = 5.20
# ############################################################
#
# Starting iteration 14...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 5.06
# #####     stabilizing functional    S = 7.48
# #####     joint weighted misfit chi^2 = 5.06
# ############################################################
#
# Starting iteration 15...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.99
# #####     stabilizing functional    S = 7.49
# #####     joint weighted misfit chi^2 = 4.99
# ############################################################
#
# Starting iteration 16...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.81
# #####     stabilizing functional    S = 7.39
# #####     joint weighted misfit chi^2 = 4.81
# ############################################################
#
# Starting iteration 17...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.72
# #####     stabilizing functional    S = 7.51
# #####     joint weighted misfit chi^2 = 4.72
# ############################################################
#
# Starting iteration 18...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.59
# #####     stabilizing functional    S = 7.52
# #####     joint weighted misfit chi^2 = 4.59
# ############################################################
#
# Starting iteration 19...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.54
# #####     stabilizing functional    S = 7.49
# #####     joint weighted misfit chi^2 = 4.54
# ############################################################
#
# Starting iteration 20...
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     SRT weighted misfit chi^2   = 4.49
# #####     stabilizing functional    S = 7.48
# #####     joint weighted misfit chi^2 = 4.49
# ############################################################
#
# All weights saved under self.weights

# %% [markdown]
# ## JME

# %%
# Without weighting
a = [a_ert, a_srt]
lam = [lam_ert, lam_srt]
beta = beta
w1 = 1 # weight ert
w2 = 1 # weight srt

ERT3 = ert.ERTManager(ert_data)
SRT3 = TravelTimeManager(tt_data)
J1 = JEI(mgr_list=[ERT3,SRT3], data_list=[ert_data,tt_data], 
         mesh=invmesh, order=q, beta=beta,smooth_factor=a)

KWs = dict(lam=lam[1], verbose=False, vTop=500, vBottom=4500, secNodes=2)
KWe = dict(lam=lam[0], verbose=False)
J1.setMethodMesh(extmesh, 0)
J1.setKWInv([KWe, KWs])
J1.setNames(['ERT','SRT'])
J1.setMethodWeights([w1,w2])

J1.runInversion('ME', maxIter=20, breakup_criterion='all', chi_limit=1)
SRT3.inv.model = 1/SRT3.inv.model

[r_est_jme, v_est_jme] = J1.getModels()
    
# J1.plotFitHistory()
# Out:
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Found 2 regions.
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# Starting Iteration 0...
# ... ERT
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Use median(data values)=619.288890298902
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [619.288890298902,...,619.288890298902]
# 26/07/23 - 20:25:19 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 20:25:57 - pyGIMLi - INFO - Found 1 regions.
# 26/07/23 - 20:25:57 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:25:57 - pyGIMLi - INFO - Creating refined mesh (secnodes: 2) to solve forward task.
# 26/07/23 - 20:25:57 - pyGIMLi - INFO - Create gradient starting model. 500: 4500
# ... SRT
# 26/07/23 - 20:25:57 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00194971 0.0010641  0.00194971 ... 0.00023161 0.0002245  0.00024393]
# 26/07/23 - 20:25:57 - pyGIMLi - INFO - Setting starting model as reference!
# Starting iteration 1...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 5.48
# #####     SRT weighted misfit chi^2   = 218.54
# #####     stabilizing functional    S = 3.69
# #####     joint weighted misfit chi^2 = 224.02
# ############################################################
#
# Starting iteration 2...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 1.32
# #####     SRT weighted misfit chi^2   = 104.36
# #####     stabilizing functional    S = 11.28
# #####     joint weighted misfit chi^2 = 105.68
# ############################################################
#
# Starting iteration 3...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.95
# #####     SRT weighted misfit chi^2   = 49.48
# #####     stabilizing functional    S = 8.65
# #####     joint weighted misfit chi^2 = 50.43
# ############################################################
#
# Starting iteration 4...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 29.14
# #####     stabilizing functional    S = 19.81
# #####     joint weighted misfit chi^2 = 30.03
# ############################################################
#
# Starting iteration 5...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 23.89
# #####     stabilizing functional    S = 8.58
# #####     joint weighted misfit chi^2 = 24.78
# ############################################################
#
# Starting iteration 6...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 20.02
# #####     stabilizing functional    S = 8.39
# #####     joint weighted misfit chi^2 = 20.91
# ############################################################
#
# Starting iteration 7...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 15.19
# #####     stabilizing functional    S = 9.32
# #####     joint weighted misfit chi^2 = 16.08
# ############################################################
#
# Starting iteration 8...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 11.87
# #####     stabilizing functional    S = 7.59
# #####     joint weighted misfit chi^2 = 12.76
# ############################################################
#
# Starting iteration 9...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 9.25
# #####     stabilizing functional    S = 7.49
# #####     joint weighted misfit chi^2 = 10.14
# ############################################################
#
# Starting iteration 10...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 8.22
# #####     stabilizing functional    S = 7.67
# #####     joint weighted misfit chi^2 = 9.11
# ############################################################
#
# Starting iteration 11...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 6.92
# #####     stabilizing functional    S = 7.79
# #####     joint weighted misfit chi^2 = 7.81
# ############################################################
#
# Starting iteration 12...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 6.63
# #####     stabilizing functional    S = 7.62
# #####     joint weighted misfit chi^2 = 7.52
# ############################################################
#
# Starting iteration 13...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 6.24
# #####     stabilizing functional    S = 7.63
# #####     joint weighted misfit chi^2 = 7.13
# ############################################################
#
# Starting iteration 14...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.56
# #####     stabilizing functional    S = 7.57
# #####     joint weighted misfit chi^2 = 6.45
# ############################################################
#
# Starting iteration 15...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.03
# #####     stabilizing functional    S = 7.62
# #####     joint weighted misfit chi^2 = 5.92
# ############################################################
#
# Starting iteration 16...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 4.40
# #####     stabilizing functional    S = 7.63
# #####     joint weighted misfit chi^2 = 5.29
# ############################################################
#
# Starting iteration 17...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 4.25
# #####     stabilizing functional    S = 7.70
# #####     joint weighted misfit chi^2 = 5.14
# ############################################################
#
# Starting iteration 18...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 4.09
# #####     stabilizing functional    S = 7.61
# #####     joint weighted misfit chi^2 = 4.98
# ############################################################
#
# Starting iteration 19...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 4.01
# #####     stabilizing functional    S = 7.61
# #####     joint weighted misfit chi^2 = 4.90
# ############################################################
#
# Starting iteration 20...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 3.79
# #####     stabilizing functional    S = 7.60
# #####     joint weighted misfit chi^2 = 4.68
# ############################################################
#
# All weights saved under self.weights

# %%
# With weighting
a = [a_ert, a_srt]
lam = [lam_ert, lam_srt]
beta = beta
w1 = 2 # weight ert
w2 = 1 # weight srt

ERT4 = ert.ERTManager(ert_data)
SRT4 = TravelTimeManager(tt_data)
J2 = JEI(mgr_list=[ERT4,SRT4], data_list=[ert_data,tt_data], 
         mesh=invmesh, order=q, beta=beta,smooth_factor=a)

KWs = dict(lam=lam[1], verbose=False, vTop=500, vBottom=4500, secNodes=2)
KWe = dict(lam=lam[0], verbose=False)
J2.setMethodMesh(extmesh, 0)
J2.setKWInv([KWe, KWs])
J2.setNames(['ERT','SRT'])
J2.setMethodWeights([w1,w2])

J2.runInversion('ME', maxIter=20, breakup_criterion='all', chi_limit=1)
SRT3.inv.model = 1/SRT3.inv.model

[r_est_jmew, v_est_jmew] = J2.getModels()

# J2.plotFitHistory()
# Out:
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Found 2 regions.
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (0) set to background.
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# Starting Iteration 0...
# ... ERT
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7632 Cells: 14948 Boundaries: 11368
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Use median(data values)=619.288890298902
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 2979 [619.288890298902,...,619.288890298902]
# 26/07/23 - 20:42:36 - pyGIMLi - INFO - Setting starting model as reference!
# 26/07/23 - 20:43:17 - pyGIMLi - INFO - Found 1 regions.
# 26/07/23 - 20:43:17 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/07/23 - 20:43:17 - pyGIMLi - INFO - Creating refined mesh (secnodes: 2) to solve forward task.
# ... SRT
# 26/07/23 - 20:43:17 - pyGIMLi - INFO - Create gradient starting model. 500: 4500
# 26/07/23 - 20:43:17 - pyGIMLi - INFO - Created startmodel from forward operator: [0.00194971 0.0010641  0.00194971 ... 0.00023161 0.0002245  0.00024393]
# 26/07/23 - 20:43:17 - pyGIMLi - INFO - Setting starting model as reference!
# Starting iteration 1...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 5.12
# #####     SRT weighted misfit chi^2   = 223.07
# #####     stabilizing functional    S = 4.16
# #####     joint weighted misfit chi^2 = 228.19
# ############################################################
#
# Starting iteration 2...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 1.28
# #####     SRT weighted misfit chi^2   = 73.42
# #####     stabilizing functional    S = 10.02
# #####     joint weighted misfit chi^2 = 74.70
# ############################################################
#
# Starting iteration 3...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.93
# #####     SRT weighted misfit chi^2   = 40.16
# #####     stabilizing functional    S = 8.71
# #####     joint weighted misfit chi^2 = 41.09
# ############################################################
#
# Starting iteration 4...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 24.40
# #####     stabilizing functional    S = 10.58
# #####     joint weighted misfit chi^2 = 25.29
# ############################################################
#
# Starting iteration 5...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 22.87
# #####     stabilizing functional    S = 7.76
# #####     joint weighted misfit chi^2 = 23.76
# ############################################################
#
# Starting iteration 6...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 16.82
# #####     stabilizing functional    S = 10.39
# #####     joint weighted misfit chi^2 = 17.70
# ############################################################
#
# Starting iteration 7...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 15.51
# #####     stabilizing functional    S = 8.47
# #####     joint weighted misfit chi^2 = 16.40
# ############################################################
#
# Starting iteration 8...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 14.08
# #####     stabilizing functional    S = 7.94
# #####     joint weighted misfit chi^2 = 14.96
# ############################################################
#
# Starting iteration 9...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 12.52
# #####     stabilizing functional    S = 8.45
# #####     joint weighted misfit chi^2 = 13.41
# ############################################################
#
# Starting iteration 10...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 11.26
# #####     stabilizing functional    S = 8.28
# #####     joint weighted misfit chi^2 = 12.14
# ############################################################
#
# Starting iteration 11...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 9.90
# #####     stabilizing functional    S = 7.96
# #####     joint weighted misfit chi^2 = 10.78
# ############################################################
#
# Starting iteration 12...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 7.89
# #####     stabilizing functional    S = 7.84
# #####     joint weighted misfit chi^2 = 8.78
# ############################################################
#
# Starting iteration 13...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 6.87
# #####     stabilizing functional    S = 7.57
# #####     joint weighted misfit chi^2 = 7.75
# ############################################################
#
# Starting iteration 14...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 6.40
# #####     stabilizing functional    S = 7.56
# #####     joint weighted misfit chi^2 = 7.28
# ############################################################
#
# Starting iteration 15...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.88
# #####     SRT weighted misfit chi^2   = 5.96
# #####     stabilizing functional    S = 7.84
# #####     joint weighted misfit chi^2 = 6.85
# ############################################################
#
# Starting iteration 16...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.67
# #####     stabilizing functional    S = 7.50
# #####     joint weighted misfit chi^2 = 6.55
# ############################################################
#
# Starting iteration 17...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.50
# #####     stabilizing functional    S = 7.67
# #####     joint weighted misfit chi^2 = 6.39
# ############################################################
#
# Starting iteration 18...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.32
# #####     stabilizing functional    S = 7.55
# #####     joint weighted misfit chi^2 = 6.21
# ############################################################
#
# Starting iteration 19...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.16
# #####     stabilizing functional    S = 7.58
# #####     joint weighted misfit chi^2 = 6.04
# ############################################################
#
# Starting iteration 20...
# Set JME weights for ERT with q=2, b=1e-10 and a=15
# Set JME weights for SRT with q=2, b=1e-10 and a=90
# #####     ERT weighted misfit chi^2   = 0.89
# #####     SRT weighted misfit chi^2   = 5.04
# #####     stabilizing functional    S = 7.59
# #####     joint weighted misfit chi^2 = 5.93
# ############################################################
#
# All weights saved under self.weights

# %% [markdown]
# ## Comparison Results

# %%
# J1.plotFitHistory()
# plt.savefig(f'C:/Users/azieg/Desktop/GIT_repositories/APG-MSc-Project-Ziegon/Figures/Ch-4/Conv_JME_{q}.pdf', 
#             bbox_inches='tight',
#             dpi=600)
# J2.plotFitHistory()
# plt.savefig(f'C:/Users/azieg/Desktop/GIT_repositories/APG-MSc-Project-Ziegon/Figures/Ch-4/Conv_JMEweighted_{q}.pdf', 
#             bbox_inches='tight',
#             dpi=600)

# %%
lim = [-10,10] # Misfit limits
label_list = ['Conventional','ME','JME - no weight','JME - weight=[2,1]']
srt_mgrs = [SRT,SRT2,SRT3,SRT4]
ert_resp = [m.inv.response.array() for m in [ERT,ERT2,ERT3,ERT4]]

cmap='coolwarm'

fig, ax = plt.subplots(4,2, figsize=(10,10))

for i in range(4):
    # Plot misfits
    e_misfit =  100*(ert_data['rhoa'].array()-ert_resp[i])/ert_data['rhoa'].array()
    showPseudosections(ert_data, e_misfit, [0,len(ert_data['a'])], 1, ax=ax[i,0], clim=lim, cmap=cmap, Type='misfit', 
                       annotation=False, colorBar=False)
    
    showTTMatrix(srt_mgrs[i], 'misfit', ax[i,1], lim=lim, cmap=cmap, colorBar=False)
    
    # Add labels
    for axis in [ax[i,0],ax[i,1]]:
        axis.text(3, 55, label_list[i], fontsize=10, bbox={'facecolor': 'white', 'alpha': 0.8, 'pad': 5})

# Adjust axes
for ax_ar in ax[:-1,:]:
    for axis in ax_ar:
        axis.set_xticks([])  
        axis.set_xlabel('')

# Add colorbar
cax = ax[-1,0].inset_axes([0.2, -0.45, 1.6, 0.1])
createColorBarOnly(ax=cax, cMin=lim[0], cMax=lim[1], logScale=False,cMap=cmap,
                   label='Misfit (%)', orientation='horizontal')
cax.set_xlabel('Misfit (%)', fontsize=12)
cax.tick_params(labelsize=12)

fig.suptitle(f'Misfit for q = {q}',fontsize=16, x=.51, y=.92)
ax[0,0].set_title('ERT',fontsize=15)
ax[0,1].set_title('SRT',fontsize=15)

for a in ax[:,0]:
    a.set_ylabel('Level', fontsize=12)
    a.set_yticks([0,20,40,60])
    
for a in ax[:,1]:
    a.set_ylabel('Source Index', fontsize=12)
    
ax[-1,0].set_xlabel('Midpoint Index', fontsize=12)
ax[-1,1].set_xlabel('Sensor Index', fontsize=12)
ax[-1,1].set_xticks([0,40,80,120])
# plt.savefig(f'C:/Users/azieg/Desktop/GIT_repositories/APG-MSc-Project-Ziegon/Figures/Ch-4/Best_misfit_comp_{q}.pdf', 
#             bbox_inches='tight',
#             dpi=600)
# Out:
# [<matplotlib.axis.XTick at 0x282ec2ebfd0>,
#  <matplotlib.axis.XTick at 0x282ec2ebfa0>,
#  <matplotlib.axis.XTick at 0x282bfe66ac0>,
#  <matplotlib.axis.XTick at 0x2830be5ad00>]

# %%
fig, ax, [cax1, cax2] = plotJointResultsComparison(invmesh, 
                                                   [r_est_con, r_est_me,r_est_jme,r_est_jmew], 
                                                   [v_est_con, v_est_me,v_est_jme,1/v_est_jmew], 
                                                   c_ert, c_srt, lim_ert, lim_srt, 
                                                   ['Conventional','ME','JME - no weight','JME - weight=[2,1]'], labels=True,
                                                   ert_marks=ert_marks, srt_marks=srt_marks, 
                                                   ert_label=ert_label, srt_label=srt_label, marks=True, 
                                                   figsize=(10,7))
for axis_ar in ax:
    for axis in axis_ar:
        pg.viewer.mpl.drawPLC(axis, geom, fillRegion=False)
        axis.set_xlim(-35,35)
        axis.set_ylim(-20,0)
fig.suptitle(f'Results for q = {q}',fontsize=16, x=0.51, y=1.05)
ax[0,0].set_title('ERT',fontsize=15)
ax[0,1].set_title('SRT',fontsize=15)
for a in ax[:,0]:
    a.set_ylabel('Z (m)', fontsize=12)
    a.set_yticks([-20,-10,0])
for a in ax[-1,:]:
    a.set_xlabel('X (m)', fontsize=12)
    a.set_xticks([-20,0,20])
    
cax1.set_xlabel(pg.unit('vel'), fontsize=12)
cax1.tick_params(labelsize=12)
cax2.set_xlabel(pg.unit('res'), fontsize=12)
cax2.tick_params(labelsize=12)
# plt.savefig(f'C:/Users/azieg/Desktop/GIT_repositories/APG-MSc-Project-Ziegon/Figures/Ch-4/Best_results_comp_{q}.pdf', 
#             bbox_inches='tight',
#             dpi=600)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 fig, ax, [cax1, cax2] = plotJointResultsComparison(invmesh,
#       2                                                    [r_est_con, r_est_me,r_est_jme,r_est_jmew],
#       3                                                    [v_est_con, v_est_me,v_est_jme,1/v_est_jmew],
#       4                                                    c_ert, c_srt, lim_ert, lim_srt,
#       5                                                    ['Conventional','ME','JME - no weight','JME - weight=[2,1]'], labels=True,
#       6                                                    ert_marks=ert_marks, srt_marks=srt_marks,
#       7                                                    ert_label=ert_label, srt_label=srt_label, marks=True,
#       8                                                    figsize=(10,7))
#       9 for axis_ar in ax:
#      10     for axis in axis_ar:
#
# TypeError: plotJointResultsComparison() missing 3 required positional arguments: 'lim_srt', 'lim_grav', and 'label_list'
